# %%
import pandas as pd

taxi_parquet_path = "data/raw/yellow_tripdata_2023-01.parquet"

df = pd.read_parquet(taxi_parquet_path)
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 5
#       1 import pandas as pd
#       3 taxi_parquet_path = "part1_taxi/data/raw/yellow_tripdata_2023-01.parquet"
# ----> 5 df = pd.read_parquet(taxi_parquet_path)
#       6 df
#
# File ~/Documents/Data Science/Big Data/COMP6940 A1/.venv/lib/python3.12/site-packages/pandas/io/parquet.py:671, in read_parquet(path, engine, columns, storage_options, dtype_backend, filesystem, filters, to_pandas_kwargs, **kwargs)
#     668 impl = get_engine(engine)
#     669 check_dtype_backend(dtype_backend)
# --> 671 return impl.read(
#     672     path,
#     673     columns=columns,
#     674     filters=filters,
#     675     storage_options=storage_options,
#     676     dtype_backend=dtype_backend,
#     677     filesystem=filesystem,
#     678     to_pandas_kwargs=to_pandas_kwargs,
#     679     **kwargs,
#     680 )
#
# ...
